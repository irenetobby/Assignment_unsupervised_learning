# %% [markdown]
# <a href="https://colab.research.google.com/github/irenetobby/Assignment_unsupervised_learning/blob/main/Assignment_unsupervised_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
df = pd.read_csv("Wine_clust.csv")
df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# 3   3.45     1480
# 4   2.93      735

# %%
df.shape
df.describe()
df.isnull().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# dtype: int64

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# %%
scaled_data[:5]
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, -1.16959318,  1.91390522,
#          0.80899739,  1.03481896, -0.65956311,  1.22488398,  0.25171685,
#          0.36217728,  1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, -2.49084714,  0.01814502,
#          0.56864766,  0.73362894, -0.82071924, -0.54472099, -0.29332133,
#          0.40605066,  1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, -0.2687382 ,  0.08835836,
#          0.80899739,  1.21553297, -0.49840699,  2.13596773,  0.26901965,
#          0.31830389,  0.78858745,  1.39514818],
#        [ 1.69154964, -0.34681064,  0.4879264 , -0.80925118,  0.93091845,
#          2.49144552,  1.46652465, -0.98187536,  1.03215473,  1.18606801,
#         -0.42754369,  1.18407144,  2.33457383],
#        [ 0.29570023,  0.22769377,  1.84040254,  0.45194578,  1.28198515,
#          0.80899739,  0.66335127,  0.22679555,  0.40140444, -0.31927553,
#          0.36217728,  0.44960118, -0.03787401]])

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11), wcss, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
for i in range(2,11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    labels = kmeans.fit_predict(scaled_data)
    print(f"Clusters: {i}, Silhouette Score: {silhouette_score(scaled_data, labels)}")
# Out:
# Clusters: 2, Silhouette Score: 0.2650328591008738
# Clusters: 3, Silhouette Score: 0.2848589191898987
# Clusters: 4, Silhouette Score: 0.25422758316007776
# Clusters: 5, Silhouette Score: 0.18362105107698137
# Clusters: 6, Silhouette Score: 0.16899191019013057
# Clusters: 7, Silhouette Score: 0.1726015561094921
# Clusters: 8, Silhouette Score: 0.16250411307671142
# Clusters: 9, Silhouette Score: 0.1738739334545086
# Clusters: 10, Silhouette Score: 0.13956723664297546

# %%
kmeans_final = KMeans(n_clusters=3, random_state=42)
df['KMeans_Cluster'] = kmeans_final.fit_predict(scaled_data)

df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  KMeans_Cluster
# 0   3.92     1065               2
# 1   3.40     1050               2
# 2   3.17     1185               2
# 3   3.45     1480               2
# 4   2.93      735               2

# %%
linked = linkage(scaled_data, method='ward')

plt.figure(figsize=(10,7))
dendrogram(linked)
plt.title("Dendrogram")
plt.show()

# %%
agglo = AgglomerativeClustering(n_clusters=3)
df['Hierarchical_Cluster'] = agglo.fit_predict(scaled_data)

df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  KMeans_Cluster  Hierarchical_Cluster
# 0   3.92     1065               2                     2
# 1   3.40     1050               2                     2
# 2   3.17     1185               2                     2
# 3   3.45     1480               2                     2
# 4   2.93      735               2                     2

# %% [markdown]
# Compare Models

# %%
silhouette_score(scaled_data, df['KMeans_Cluster'])
silhouette_score(scaled_data, df['Hierarchical_Cluster'])
# Out:
# np.float64(0.2774439826952265)

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import numpy as np

wcss = []
silhouette_scores = []

cluster_range = range(2, 11)

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)

for i in cluster_range:
    kmeans = KMeans(n_clusters=i, random_state=42)
    labels = kmeans.fit_predict(scaled_data)
    score = silhouette_score(scaled_data, labels)
    silhouette_scores.append(score)

# Find best cluster based on highest silhouette score
best_cluster = cluster_range[np.argmax(silhouette_scores)]
best_score = max(silhouette_scores)

print("Silhouette Scores:")
for i, score in zip(cluster_range, silhouette_scores):
    print(f"Clusters: {i} --> Score: {score:.4f}")

print("\n✅ Optimal Number of Clusters (based on Silhouette Score):", best_cluster)
print("Best Silhouette Score:", round(best_score, 4))

# Optional: Plot Elbow
plt.figure(figsize=(8,5))
plt.plot(range(1,11), wcss, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.xticks(range(1,11))
plt.show()
# Out:
# Silhouette Scores:
# Clusters: 2 --> Score: 0.2650
# Clusters: 3 --> Score: 0.2849
# Clusters: 4 --> Score: 0.2542
# Clusters: 5 --> Score: 0.1836
# Clusters: 6 --> Score: 0.1690
# Clusters: 7 --> Score: 0.1726
# Clusters: 8 --> Score: 0.1625
# Clusters: 9 --> Score: 0.1739
# Clusters: 10 --> Score: 0.1396
#
# ✅ Optimal Number of Clusters (based on Silhouette Score): 3
# Best Silhouette Score: 0.2849

# %%
# 1. Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# 2. Load dataset
df = pd.read_csv("Wine_clust.csv")
print(df.head())

# 3. Standardize the data (IMPORTANT for DBSCAN)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# 4. Build DBSCAN model
dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters = dbscan.fit_predict(X_scaled)

# 5. Add cluster labels to dataframe
df['Cluster'] = clusters
print(df['Cluster'].value_counts())

# 6. Check number of clusters (excluding noise = -1)
n_clusters = len(set(clusters)) - (1 if -1 in clusters else 0)
print("Number of clusters:", n_clusters)

# 7. Silhouette Score (only if clusters > 1)
if n_clusters > 1:
    score = silhouette_score(X_scaled, clusters)
    print("Silhouette Score:", score)

# 8. Visualize (using first two features)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=clusters, cmap='rainbow')
plt.title("DBSCAN Clustering")
plt.show()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# 3   3.45     1480
# 4   2.93      735
# Cluster
# -1    178
# Name: count, dtype: int64
# Number of clusters: 0
